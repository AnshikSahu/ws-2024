# %%
# !pip install apache-flink
# Out:
# Collecting apache-flink
#   Using cached apache_flink-1.20.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting py4j==0.10.9.7 (from apache-flink)
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /Users/anshiksahu/Desktop/.venv/lib/python3.11/site-packages (from apache-flink) (2.9.0.post0)
# Collecting apache-beam<2.49.0,>=2.43.0 (from apache-flink)
#   Using cached apache_beam-2.48.0-py3-none-any.whl
# Collecting cloudpickle>=2.2.0 (from apache-flink)
#   Using cached cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting avro-python3!=1.9.2,>=1.8.1 (from apache-flink)
#   Using cached avro_python3-1.10.2-py3-none-any.whl
# Collecting pytz>=2018.3 (from apache-flink)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting fastavro!=1.8.0,>=1.1.0 (from apache-flink)
#   Using cached fastavro-1.9.7-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Collecting requests>=2.26.0 (from apache-flink)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting protobuf>=3.19.0 (from apache-flink)
#   Using cached protobuf-5.29.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting numpy>=1.22.4 (from apache-flink)
#   Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas>=1.3.0 (from apache-flink)
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting pyarrow>=5.0.0 (from apache-flink)
#   Using cached pyarrow-18.1.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting httplib2>=0.19.0 (from apache-flink)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting ruamel.yaml>=0.18.4 (from apache-flink)
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting apache-flink-libraries<1.20.1,>=1.20.0 (from apache-flink)
#   Using cached apache_flink_libraries-1.20.0-py2.py3-none-any.whl
# Collecting pemja==0.4.1 (from apache-flink)
#   Using cached pemja-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting find-libpython (from pemja==0.4.1->apache-flink)
#   Using cached find_libpython-0.4.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting crcmod<2.0,>=1.7 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached crcmod-1.7-cp311-cp311-macosx_11_0_arm64.whl
# Collecting orjson<4.0 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached orjson-3.10.12-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached dill-0.3.1.1-py3-none-any.whl
# Collecting cloudpickle>=2.2.0 (from apache-flink)
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,<2,>=1.33.1 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Downloading grpcio-1.68.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.9 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached hdfs-2.7.3-py3-none-any.whl
# Collecting numpy>=1.22.4 (from apache-flink)
#   Using cached numpy-1.24.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached objsize-0.6.1-py3-none-any.whl.metadata (10 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached pymongo-4.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting proto-plus<2,>=1.7.1 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf>=3.19.0 (from apache-flink)
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Collecting pydot<2,>=1.2.0 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting regex>=2020.6.8 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Users/anshiksahu/Desktop/.venv/lib/python3.11/site-packages (from apache-beam<2.49.0,>=2.43.0->apache-flink) (4.12.2)
# Collecting zstandard<1,>=0.18.0 (from apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow>=5.0.0 (from apache-flink)
#   Using cached pyarrow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2>=0.19.0->apache-flink)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.3.0->apache-flink)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/anshiksahu/Desktop/.venv/lib/python3.11/site-packages (from python-dateutil<3,>=2.8.0->apache-flink) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.26.0->apache-flink)
#   Downloading charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26.0->apache-flink)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->apache-flink)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26.0->apache-flink)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.18.4->apache-flink)
#   Using cached ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl.metadata (2.7 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam<2.49.0,>=2.43.0->apache-flink)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Using cached apache_flink-1.20.0-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
# Using cached pemja-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (53 kB)
# Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Using cached fastavro-1.9.7-cp311-cp311-macosx_10_9_universal2.whl (1.0 MB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached numpy-1.24.4-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 12.6 MB/s eta 0:00:00 0:00:01
# Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
# Using cached pyarrow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl (22.3 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading grpcio-1.68.1-cp311-cp311-macosx_10_9_universal2.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 14.3 MB/s eta 0:00:00 0:00:01
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Using cached objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Using cached orjson-3.10.12-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (248 kB)
# Using cached proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Using cached pymongo-4.10.1-cp311-cp311-macosx_11_0_arm64.whl (889 kB)
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
# Using cached ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl (132 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl (633 kB)
# Using cached find_libpython-0.4.0-py3-none-any.whl (8.7 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: pytz, py4j, find-libpython, docopt, crcmod, zstandard, urllib3, tzdata, ruamel.yaml.clib, regex, pyparsing, protobuf, pemja, orjson, objsize, numpy, idna, grpcio, fasteners, fastavro, dnspython, dill, cloudpickle, charset-normalizer, certifi, avro-python3, apache-flink-libraries, ruamel.yaml, requests, pymongo, pydot, pyarrow, proto-plus, pandas, httplib2, hdfs, apache-beam, apache-flink
# Successfully installed apache-beam-2.48.0 apache-flink-1.20.0 apache-flink-libraries-1.20.0 avro-python3-1.10.2 certifi-2024.8.30 charset-normalizer-3.4.0 cloudpickle-2.2.1 crcmod-1.7 dill-0.3.1.1 dnspython-2.7.0 docopt-0.6.2 fastavro-1.9.7 fasteners-0.19 find-libpython-0.4.0 grpcio-1.68.1 hdfs-2.7.3 httplib2-0.22.0 idna-3.10 numpy-1.24.4 objsize-0.6.1 orjson-3.10.12 pandas-2.2.3 pemja-0.4.1 proto-plus-1.25.0 protobuf-4.23.4 py4j-0.10.9.7 pyarrow-11.0.0 pydot-1.4.2 pymongo-4.10.1 pyparsing-3.2.0 pytz-2024.2 regex-2024.11.6 requests-2.32.3 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.12 tzdata-2024.2 urllib3-2.2.3 zstandard-0.23.0

# %%
from pyflink.datastream import StreamExecutionEnvironment
from pyflink.common.serialization import SimpleStringSchema
from pyflink.datastream.connectors.file_system import FileSource, StreamFormat
from pyflink.common.watermark_strategy import WatermarkStrategy
from pyflink.common.typeinfo import Types
from pyflink.java_gateway import get_gateway
gateway = get_gateway()
string_class = gateway.jvm.String
string_array = gateway.new_array(string_class, 0)
stream_env = gateway.jvm.org.apache.flink.streaming.api.environment.StreamExecutionEnvironment
j_stream_exection_environment = stream_env.createRemoteEnvironment(
    "localhost", 
    8081, 
    string_array
)

# Step 1: Initialize the streaming environment
env = StreamExecutionEnvironment(j_stream_exection_environment).get_execution_environment()

# Step 2: Define the file source
event_file_path = "user_interactions.csv"

source = FileSource.for_record_stream_format(
    StreamFormat.text_line_format(),  # Reads the file line by line
    event_file_path
).build()

# Step 3: Define a basic watermark strategy
watermark_strategy = WatermarkStrategy.for_monotonous_timestamps()

# Step 4: Add the source to the environment
event_stream = env.from_source(
    source,
    watermark_strategy=watermark_strategy,  # Use the basic watermark strategy
    source_name="event_source"
)

# Step 5: Process the events
def process_event(event):
    try:
        # Parse the CSV line
        event_time, event_type, event_value = event.split(",")
        event_value = float(event_value)
        if event_type == "click":
            return f"Processed Click Event: {event_time}, {event_value * 1.1}"
        else:
            return f"Ignored Event: {event_type}"
    except Exception as e:
        return f"Error processing: {event} | {str(e)}"

processed_stream = event_stream.map(process_event, output_type=Types.STRING())

# Step 6: Print the processed events
processed_stream.print()

# Step 7: Execute the pipeline
env.execute("File Source Event Processing")
# Out:
# 2> Processed Click Event: 2024-12-01 12:00:00, 1.6500000000000001
# 2> Ignored Event: scroll
# 2> Processed Click Event: 2024-12-01 12:00:10, 3.3000000000000003
# 2> Ignored Event: scroll
